# %% [markdown]
# # Deep Q Network with Pong
#
# DQN was created by DeepMind researchers, achieving superhuman performance on many Atari games (https://deepmind.com/research/dqn/). What made the accomplishments of DQN even more impressive is that the DQN had nearly the same architecture and hyperparameter settings for each game (ie no game specific knowledge or set up) and the only inputs to the DQN were the screen pixels. The main parts of the DQN are Q learning, the neural net, experience replay, target network updating, and data/environment pre-processing.

# %%
# !pip install swig
# !pip install gymnasium[box2d]
# Out:
# Requirement already satisfied: swig in c:\users\student\rl-intersection\venv\lib\site-packages (4.1.1)
# WARNING: You are using pip version 21.3.1; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\student\RL-Intersection\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: gymnasium[box2d] in c:\users\student\rl-intersection\venv\lib\site-packages (0.28.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\student\rl-intersection\venv\lib\site-packages (from gymnasium[box2d]) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\student\rl-intersection\venv\lib\site-packages (from gymnasium[box2d]) (4.13.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\student\rl-intersection\venv\lib\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\student\rl-intersection\venv\lib\site-packages (from gymnasium[box2d]) (4.4.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\student\rl-intersection\venv\lib\site-packages (from gymnasium[box2d]) (1.24.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\student\rl-intersection\venv\lib\site-packages (from gymnasium[box2d]) (2.2.0)
# Requirement already satisfied: swig==4.* in c:\users\student\rl-intersection\venv\lib\site-packages (from gymnasium[box2d]) (4.1.1)
# Requirement already satisfied: pygame==2.1.3 in c:\users\student\rl-intersection\venv\lib\site-packages (from gymnasium[box2d]) (2.1.3)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\student\rl-intersection\venv\lib\site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\student\rl-intersection\venv\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium[box2d]) (3.11.0)
# WARNING: You are using pip version 21.3.1; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\student\RL-Intersection\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import gymnasium as gym
import numpy as np

# %%
# check and use GPU if available if not use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Experience Replay Buffer
#
# Q learning is an off-policy method. In off-policy methods we often save samples and then train on them. DQN has a memory buffer that stores state, action, reward, done condition, and next state samples. In the training loop, DQN will sample from this memory buffer and train on the saved samples. The replay buffer is essentially a queue that we randomly sample from. When the queue gets full we replace the first element of the queue.

# %%
# replay buffer from and some code based on https://github.com/sfujim/TD3

# create replay buffer of tuples of (state, next_state, action, reward, done)
class ReplayBuffer():
    def __init__(self, max_size=1e6):
        self.storage = []
        self.max_size = max_size
        self.ptr = 0

    def add(self, data):
        if len(self.storage) == self.max_size:
            self.storage[int(self.ptr)] = data
            self.ptr = (self.ptr + 1) % self.max_size
        else:
            self.storage.append(data)

    def sample(self, batch_size):
        ind = np.random.randint(0, len(self.storage), size=batch_size)
        x, y, u, r, d = [], [], [], [], []

        for i in ind: 
            X, Y, U, R, D = self.storage[i]
            x.append(np.array(X, copy=False))
            y.append(np.array(Y, copy=False))
            u.append(np.array(U, copy=False))
            r.append(np.array(R, copy=False))
            d.append(np.array(D, copy=False))

        return np.array(x), np.array(y), np.array(u).reshape(-1,1), np.array(r).reshape(-1,1), np.array(d).reshape(-1,1)

# %% [markdown]
# ### Environment Wrappers
#
# Wrappers modify gym environments. Wrappers can change the observation, reward, done, and info returns. Wrappers can also change the gym functions like step() and reset(). We include and use some common wrappers used in Atari games in the cells below. To use a wrapper, feed the gym env into the wrapper function like in the next cell. Sometimes problems require their own customized wrappers.

# %% [markdown]
# ### Pong
#
# In this notebook we'll train an agent to play the classic Atari game Pong. In Pong the agent controls a paddle and tries to hit a ball past the opponents paddle to score a point. The agent gets a positive reward when scoring a point and a negative reward when the opponent scores a point. The episode ends when a set number of points are reached.

# %%
env = gym.make('LunarLander-v2', render_mode='rgb_array')
env.reset()

prev_screen = env.render()
plt.imshow(prev_screen)

for i in range(200):
    env.render()
    action = env.action_space.sample()
    obs, reward, termination, truncation, info = env.step(action)
    if termination or truncation:
        env.reset()

env.close()

# %% [markdown]
# ### Deep Q Network
#
# The Deep Q Network is from the original DQN paper and is sometimes referred to as the Nature CNN (since the article was published in Nature). Compared to state of the art CNNs in image recognition, the Nature CNN is quite simple. There are only three convolutional layers, followed by a fully connected (dense) layer and a linear layer. All but the linear layer have ReLU activations.

# %%
# create Deep Q Network Class by inheriting from torch.nn.Module
# based on Nature CNN from OpenAI baselines: https://github.com/openai/baselines/blob/1b092434fc51efcb25d6650e287f07634ada1e08/baselines/common/models.py
           
class DeepQNetwork(nn.Module):
    def __init__(self, observation_size, action_size, hidden_size):
        super(DeepQNetwork, self).__init__()
        self.fc_layer = nn.Linear(observation_size, hidden_size)
        # V(s) value of the state
        self.dueling_value = nn.Linear(hidden_size, 1)
        # Q(s,a) Q values of the state-action combination
        self.dueling_action = nn.Linear(hidden_size, action_size)
    
    def forward(self, x):
        x = F.relu(self.fc_layer(x))
        # get advantage by subtracting dueling action mean from dueling action
            # then add estimated state value
        action_advantage = self.dueling_action(x) - self.dueling_action(x).mean(dim=1, keepdim=True)
        state_value = self.dueling_value(x)
        return state_value + action_advantage

    def get_state_value(self, x):
        x = F.relu(self.fc_layer(x))
        return self.dueling_value(x)

class ActorNet(nn.Module):
    def __init__(self, state_size, action_size, hidden_size):
        super(ActorNet, self).__init__()
        self.dense_layer_1 = nn.Linear(state_size, hidden_size)
        self.dense_layer_2 = nn.Linear(hidden_size, hidden_size)
        self.output = nn.Linear(hidden_size, action_size)

    def forward(self, x):
        x = torch.clamp(x,-1.1,1.1)
        x = F.relu(self.dense_layer_1(x))
        x = F.relu(self.dense_layer_2(x))
        return F.softmax(self.output(x),dim=-1) + 1e-8 #-1 to take softmax of last dimension

# %% [markdown]
# ### DQNAgent Class
#
# We create a DQNAgent class. The agent has a train network for learning a policy and a target network for performing target network updates. The agent has a select_action() function for sampling an action based on the epsilon-greedy method. The agent has a train() function, in which the agent samples from the replay buffer and updates the neural network parameters to improve its policy. The agent also has a update_target_network() function for updating the target network parameters with the training network parameters.

# %%
class DQNActorCriticHybridAgent():
    def __init__(self, observation_size, action_size, hidden_size, learning_rate, actor_lr, entropy_coeff):
        self.action_size = action_size
        self.observation_size = observation_size
        self.train_net = DeepQNetwork(observation_size, action_size, hidden_size).to(device)
        self.target_net = DeepQNetwork(observation_size, action_size, hidden_size).to(device)
        self.target_net.load_state_dict(self.train_net.state_dict())
        self.optimizer = optim.Adam(self.train_net.parameters(), lr=learning_rate)

        self.actor_net = ActorNet(observation_size, action_size, hidden_size).to(device)
        self.actor_optimizer = optim.Adam(self.actor_net.parameters(), lr=actor_lr)
        self.discount = discount
        self.entropy_coeff = entropy_coeff


    # def select_action(self, s, eps):
    #     # select action according to epsilon-greedy method
    #     if np.random.rand() <= eps:
    #         a = env.action_space.sample()
    #     else:
    #         # greedy action is the largest Q value from the train network based on the input
    #         with torch.no_grad():
    #             input_state = torch.FloatTensor(np.array(s)).unsqueeze(0).to(device)
    #             a = self.train_net(input_state).max(1)[1]#.view(1, 1)#.detach().cpu().numpy()[0]
    #             a = int(a)
    #     return a
    def select_action(self, state):
        #get action probs then randomly sample from the probabilities
        with torch.no_grad():
            input_state = torch.FloatTensor(state).to(device)
            action_probs = self.actor_net(input_state)
            #detach and turn to numpy to use with np.random.choice()
            action_probs = action_probs.detach().cpu().numpy()
            action = np.random.choice(np.arange(self.action_size), p=action_probs)
        return action


    def train(self, replay_buffer, batch_size, discount):
        # train the training network
        # sample a batch from the replay buffer
        x0, x1, a, r, d = replay_buffer.sample(batch_size)
        # turn batches into tensors and attack to GPU if available
        state_batch = torch.FloatTensor(x0).to(device)
        next_state_batch = torch.FloatTensor(x1).to(device)
        action_batch = torch.LongTensor(a).to(device)
        reward_batch = torch.FloatTensor(r).to(device)
        done_batch = torch.FloatTensor(1. - d).to(device)

        # get train net Q values
        train_q = self.train_net(state_batch).gather(1, action_batch)

        # get target net Q values
        with torch.no_grad():
            # Vanilla DQN: get target values from target net
#             target_net_q = reward_batch + done_batch * discount * \
#                      torch.max( self.target_net(next_state_batch).detach(), dim=1)[0].view(batch_size, -1)

            # Double DQN: get argmax values from train network, use argmax in target network
            train_argmax = self.train_net(next_state_batch).max(1)[1].view(batch_size, 1)
            target_net_q = reward_batch + done_batch * discount * \
                    self.target_net(next_state_batch).gather(1, train_argmax)

        # get loss between train q values and target q values
            # DQN implementations typically use MSE loss or Huber loss (smooth_l1_loss is similar to Huber)
        #loss_fn = nn.MSELoss()
        #loss = loss_fn(train_q, target_net_q)
        loss = F.smooth_l1_loss(train_q, target_net_q)

        # optimize the parameters with the loss
        self.optimizer.zero_grad()
        loss.backward()
        for param in self.train_net.parameters():
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step()
        # we return the loss so we can monitor loss and debug the network if necessary
        return loss.detach().cpu().numpy()


    def update_target_network(self, num_iter, update_every):
        # update target network every so often
        # hard target network update: updates target network fully with train network params
        if num_iter % update_every == 0:
            #print("Updating target network parameters")
            self.target_net.load_state_dict(self.train_net.state_dict())


    def update_target_network_soft(self, num_iter, update_every, update_tau=0.001):
        # soft target network update: update target network with mixture of train and target
        if num_iter % update_every == 0:
            for target_var, var in zip(self.target_net.parameters(), self.train_net.parameters()):
                target_var.data.copy_((1.-update_tau) * target_var.data + (update_tau) * var.data)


    def train_actor(self, state_list, action_list, reward_list, next_state_list, done_list):

        # create tensors
        state_t = torch.FloatTensor(state_list).to(device)
        next_state_t = torch.FloatTensor(next_state_list).to(device)
        action_t = torch.LongTensor(action_list).to(device).view(-1,1)
        reward_t = torch.FloatTensor(reward_list).to(device).view(-1,1)
        done_t = torch.FloatTensor(done_list).to(device).view(-1,1) #flipping 0 and 1 in RL training loop

        # get critic estimate
        with torch.no_grad():
            critic_t = self.target_net.get_state_value(state_t).view(-1,1)
            critic_td_t = reward_t + done_t * self.discount * self.target_net.get_state_value(next_state_t).view(-1,1)
            advantage_t = critic_td_t - critic_t

        # get action probabilities
        action_probs = self.actor_net(state_t)
        selected_action_prob = action_probs.gather(1, action_t)
        # calculate entropy loss
        entropy_loss = -torch.sum(action_probs*torch.log(action_probs), dim=1)
        # calculate actor loss
        actor_loss = torch.mean(-torch.log(selected_action_prob) * advantage_t + self.entropy_coeff*entropy_loss)
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        return actor_loss.detach().cpu().numpy()

# %% [markdown]
# ### Target Network Updating
#
# DQN has two networks: a train network and a target network. The target network provides the next-state Q values for the Q learning update. We use the next-state Q values to update the train network. Periodically we then update target network variables with the train network variables. Using a target network increases stability and convergence of the DQN.
#
# ### Hyperparameters
#
# Hyperparameters are a variety of arguments that are usually tuned to help produce the best performing agents. Hyperparameter choice can be tricky as poor hyperparameter choice can prevent an agent from learning anything. The best choice depends on the algorithm and problem. Two basic methods that are used are random search, where you randomly pick hyperparameter values from a predefined range of values, and grid search where you systematically try all values and combinations based on a predefined grid of values.

# %%
# Initialize env and set up hyperparameters
env = gym.make('LunarLander-v2', render_mode='rgb_array')
action_size = env.action_space.n
observation_size = env.observation_space.shape[0]

# set seed
seed = 31
#env.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# hyperparameters
timesteps = 200000 # run env for this many time steps
hidden_size = 256   # side of hidden layer of FFNN that connects CNN to outputs
learning_rate = 0.01 # learning rate of optimizer
batch_size = 64    # size of batch trained on
start_training_after = 1001 # start training NN after this many timesteps
discount = 0.99 # discount future states by

actor_lr = 0.00005 # learning rate for actor
reward_scale = 0.01 #scale reward by this amount
entropy_coeff = 0.000001

update_target_every = 1 # update target network every this steps
tau = 0.001

# create replay buffer
replay_size = 100000 # size of replay buffer
replay_buffer = ReplayBuffer(max_size=replay_size)

# create DQN Agent
agent = DQNActorCriticHybridAgent(observation_size, action_size, hidden_size, learning_rate, actor_lr, entropy_coeff)

# %% [markdown]
# ### The RL Training Loop
#
# In the loop, we iterate through our episodes and then the timesteps within the episodes. We stop training the agent based on some stopping condition like a max episode value, a max timestep value, or if the agent's performance reaches a certain level.
#
# In each episode and at each timestep the agent selects an action, calls env.step(), and stores the sample in the replay buffer. The agent will also train the training neural network and periodically update the target network. When an episode is done the env is reset.

# %%
stats_rewards_list = [] # store stats for plotting in this
stats_every = 10 # print stats every this many episodes
total_reward = 0
episode = 1
episode_length = 0
stats_loss = 0.
stats_actor_loss = []

state, _ = env.reset(seed=seed)
state_list, action_list, reward_list, next_state_list, done_list = [], [], [], [], []

for ts in range(timesteps):
    #env.render()
    # select an action from the agent's policy
    action = agent.select_action(state)
            
    # enter action into the env
    next_state, reward, termination, truncation, info = env.step(action)
    total_reward += reward
    episode_length += 1
    # end episode early
    if total_reward < -250:
        truncation = 1

    # store agent's trajectory
    state_list.append(state)
    action_list.append(action)
    reward_list.append(reward * reward_scale)
    next_state_list.append(next_state)
    done_list.append(1. - float(termination))

    # train the actor
    actor_loss = agent.train_actor(state_list, action_list, reward_list, next_state_list, done_list)
    stats_actor_loss.append(actor_loss)

    # add experience to replay buffer
    replay_buffer.add((state, next_state, action, reward, float(termination)))
    
    if ts > start_training_after:
        # train the agent
        stats_loss += agent.train(replay_buffer, batch_size, discount)
        # update the target network every (if conditions are met in update_target_network)
        #dqn_agent.update_target_network(ts, update_target_every) # hard target update
        agent.update_target_network_soft(ts, update_target_every, tau) # soft target update
    
    if termination or truncation:
        state, _ = env.reset()
        state_list, action_list, reward_list, next_state_list, done_list = [], [], [], [], []
        stats_rewards_list.append((episode, total_reward, episode_length))
        episode += 1
        total_reward = 0
        episode_length = 0

        if ts > start_training_after and episode % stats_every == 0:
            print('Episode: {}'.format(episode),
                'Timestep: {}'.format(ts),
                'Total reward: {:.1f}'.format(np.mean(stats_rewards_list[-stats_every:],axis=0)[1]),
                'Episode length: {:.1f}'.format(np.mean(stats_rewards_list[-stats_every:],axis=0)[2]),
                'Loss: {:.4f}'.format(stats_loss),
                'Actor Loss: {:.4f}'.format(np.mean(stats_actor_loss)))
            stats_actor_loss = []
            stats_loss = 0.
        
        # stopping condition for training if agent reaches the amount of reward
        if len(stats_rewards_list) > stats_every and np.mean(stats_rewards_list[-stats_every:],axis=0)[1] > 190:
            print("Stopping at episode {} with average rewards of {} in last {} episodes".
                format(episode, np.mean(stats_rewards_list[-stats_every:],axis=0)[1], stats_every))
            break

    else:
        state = next_state
# Out:
# Episode: 70 Timestep: 21948 Total reward: -59.5 Episode length: 712.4 Loss: 10126.7131 Actor Loss: -3.4762
# Episode: 80 Timestep: 31845 Total reward: -140.4 Episode length: 989.7 Loss: 13086.4050 Actor Loss: -3.2363
# Episode: 90 Timestep: 39519 Total reward: -91.9 Episode length: 767.4 Loss: 9761.5929 Actor Loss: -3.1199
# Episode: 100 Timestep: 45677 Total reward: -61.1 Episode length: 615.8 Loss: 8007.4303 Actor Loss: -3.0521
# Episode: 110 Timestep: 49366 Total reward: -49.1 Episode length: 368.9 Loss: 5236.2046 Actor Loss: -2.1801
# Episode: 120 Timestep: 50409 Total reward: -49.5 Episode length: 104.3 Loss: 1619.2159 Actor Loss: -0.0478
# Episode: 130 Timestep: 51231 Total reward: -79.4 Episode length: 82.2 Loss: 1329.8001 Actor Loss: 0.0689
# Episode: 140 Timestep: 51921 Total reward: -106.5 Episode length: 69.0 Loss: 1241.1663 Actor Loss: 0.0310
# Episode: 150 Timestep: 52607 Total reward: -104.9 Episode length: 68.6 Loss: 1275.5302 Actor Loss: 0.1535
# Episode: 160 Timestep: 53272 Total reward: -116.6 Episode length: 66.5 Loss: 1217.1055 Actor Loss: 0.1351
# Episode: 170 Timestep: 53997 Total reward: -121.3 Episode length: 72.5 Loss: 1588.9032 Actor Loss: -0.1418
# Episode: 180 Timestep: 54683 Total reward: -118.7 Episode length: 68.6 Loss: 1637.1162 Actor Loss: 0.1438
# Episode: 190 Timestep: 55334 Total reward: -118.4 Episode length: 65.1 Loss: 1355.8363 Actor Loss: 0.1369
# Episode: 200 Timestep: 55986 Total reward: -111.4 Episode length: 65.2 Loss: 1591.5939 Actor Loss: 0.0677
# Episode: 210 Timestep: 56690 Total reward: -112.9 Episode length: 70.4 Loss: 1655.1224 Actor Loss: 0.0926
# Episode: 220 Timestep: 57347 Total reward: -110.7 Episode length: 65.7 Loss: 1652.7677 Actor Loss: 0.0388
# Episode: 230 Timestep: 58060 Total reward: -112.3 Episode length: 71.3 Loss: 1846.4645 Actor Loss: 0.0611
# Episode: 240 Timestep: 58751 Total reward: -115.3 Episode length: 69.1 Loss: 1750.6610 Actor Loss: 0.0734
# Episode: 250 Timestep: 59429 Total reward: -117.3 Episode length: 67.8 Loss: 1914.9283 Actor Loss: 0.0735
# Episode: 260 Timestep: 60145 Total reward: -114.1 Episode length: 71.6 Loss: 1964.7012 Actor Loss: 0.0638
# Episode: 270 Timestep: 60844 Total reward: -122.6 Episode length: 69.9 Loss: 1834.6458 Actor Loss: 0.0655
# Episode: 280 Timestep: 61543 Total reward: -116.5 Episode length: 69.9 Loss: 1913.1572 Actor Loss: 0.0105
# Episode: 290 Timestep: 62279 Total reward: -115.9 Episode length: 73.6 Loss: 2192.6287 Actor Loss: -0.1329
# Episode: 300 Timestep: 62998 Total reward: -122.1 Episode length: 71.9 Loss: 1981.1551 Actor Loss: 0.0941
# Episode: 310 Timestep: 63776 Total reward: -117.2 Episode length: 77.8 Loss: 2297.9215 Actor Loss: -0.0251
# Episode: 320 Timestep: 64513 Total reward: -112.2 Episode length: 73.7 Loss: 2149.6261 Actor Loss: -0.0059
# Episode: 330 Timestep: 65192 Total reward: -106.1 Episode length: 67.9 Loss: 2099.2835 Actor Loss: 0.0497
# Episode: 340 Timestep: 65857 Total reward: -116.1 Episode length: 66.5 Loss: 2123.1964 Actor Loss: 0.1245
# Episode: 350 Timestep: 66563 Total reward: -108.8 Episode length: 70.6 Loss: 2344.5476 Actor Loss: -0.0545
# Episode: 360 Timestep: 67293 Total reward: -113.9 Episode length: 73.0 Loss: 2584.3272 Actor Loss: 0.1014
# Episode: 370 Timestep: 68001 Total reward: -111.5 Episode length: 70.8 Loss: 2298.9349 Actor Loss: 0.1009
# Episode: 380 Timestep: 68733 Total reward: -111.9 Episode length: 73.2 Loss: 2534.0061 Actor Loss: 0.1093
# Episode: 390 Timestep: 69428 Total reward: -114.8 Episode length: 69.5 Loss: 2698.0105 Actor Loss: -0.0057
# Episode: 400 Timestep: 70145 Total reward: -116.5 Episode length: 71.7 Loss: 2758.0510 Actor Loss: 0.0977
# Episode: 410 Timestep: 70882 Total reward: -116.5 Episode length: 73.7 Loss: 2884.1421 Actor Loss: 0.1226
# Episode: 420 Timestep: 71561 Total reward: -117.2 Episode length: 67.9 Loss: 2797.1938 Actor Loss: 0.1062
# Episode: 430 Timestep: 72196 Total reward: -105.6 Episode length: 63.5 Loss: 2634.7242 Actor Loss: 0.0277
# Episode: 440 Timestep: 72907 Total reward: -105.2 Episode length: 71.1 Loss: 2870.4361 Actor Loss: 0.1529
# Episode: 450 Timestep: 73554 Total reward: -108.2 Episode length: 64.7 Loss: 2527.2506 Actor Loss: 0.2624
# Episode: 460 Timestep: 74241 Total reward: -112.6 Episode length: 68.7 Loss: 2888.4185 Actor Loss: 0.0964
# Episode: 470 Timestep: 74971 Total reward: -111.7 Episode length: 73.0 Loss: 3201.3496 Actor Loss: 0.2377
# Episode: 480 Timestep: 75654 Total reward: -114.8 Episode length: 68.3 Loss: 3036.3362 Actor Loss: 0.5500
# Episode: 490 Timestep: 76352 Total reward: -122.8 Episode length: 69.8 Loss: 3214.6065 Actor Loss: 0.9170
# Episode: 500 Timestep: 77027 Total reward: -108.9 Episode length: 67.5 Loss: 3449.2569 Actor Loss: 0.8915
# Episode: 510 Timestep: 77652 Total reward: -112.8 Episode length: 62.5 Loss: 3186.0322 Actor Loss: 1.0021
# Episode: 520 Timestep: 78367 Total reward: -115.4 Episode length: 71.5 Loss: 3460.8031 Actor Loss: 0.4654
# Episode: 530 Timestep: 79061 Total reward: -120.6 Episode length: 69.4 Loss: 3579.2466 Actor Loss: 0.2836
# Episode: 540 Timestep: 79782 Total reward: -123.7 Episode length: 72.1 Loss: 3829.7318 Actor Loss: 0.1344
# Episode: 550 Timestep: 80529 Total reward: -127.8 Episode length: 74.7 Loss: 3861.3163 Actor Loss: 0.3972
# Episode: 560 Timestep: 81189 Total reward: -120.4 Episode length: 66.0 Loss: 3550.6003 Actor Loss: 0.2918
# Episode: 570 Timestep: 81878 Total reward: -117.5 Episode length: 68.9 Loss: 3673.1589 Actor Loss: 0.0373
# Episode: 580 Timestep: 82639 Total reward: -129.3 Episode length: 76.1 Loss: 4150.7978 Actor Loss: -0.1898
# Episode: 590 Timestep: 83339 Total reward: -131.7 Episode length: 70.0 Loss: 3909.8150 Actor Loss: -0.6233
# Episode: 600 Timestep: 84047 Total reward: -140.5 Episode length: 70.8 Loss: 3832.0281 Actor Loss: 0.1557
# Episode: 610 Timestep: 84759 Total reward: -137.0 Episode length: 71.2 Loss: 3899.2222 Actor Loss: 0.0286
# Episode: 620 Timestep: 85486 Total reward: -136.1 Episode length: 72.7 Loss: 4413.1933 Actor Loss: -0.0715
# Episode: 630 Timestep: 86132 Total reward: -142.8 Episode length: 64.6 Loss: 3755.5177 Actor Loss: 0.2537
# Episode: 640 Timestep: 86789 Total reward: -133.3 Episode length: 65.7 Loss: 3612.1322 Actor Loss: 0.0538
# Episode: 650 Timestep: 87524 Total reward: -147.8 Episode length: 73.5 Loss: 4643.1560 Actor Loss: 0.2454
# Episode: 660 Timestep: 88284 Total reward: -134.4 Episode length: 76.0 Loss: 4601.0690 Actor Loss: -0.0927
# Episode: 670 Timestep: 88958 Total reward: -149.0 Episode length: 67.4 Loss: 3875.5040 Actor Loss: 0.1584
# Episode: 680 Timestep: 89710 Total reward: -160.7 Episode length: 75.2 Loss: 4526.6761 Actor Loss: 0.0746
# Episode: 690 Timestep: 90407 Total reward: -165.9 Episode length: 69.7 Loss: 4623.0374 Actor Loss: -0.3370
# Episode: 700 Timestep: 91127 Total reward: -131.7 Episode length: 72.0 Loss: 4793.1177 Actor Loss: 0.0726
# Episode: 710 Timestep: 91814 Total reward: -152.9 Episode length: 68.7 Loss: 4459.1648 Actor Loss: 0.2419
# Episode: 720 Timestep: 92474 Total reward: -156.0 Episode length: 66.0 Loss: 4389.3665 Actor Loss: -1.3670
# Episode: 730 Timestep: 93269 Total reward: -151.4 Episode length: 79.5 Loss: 5550.0914 Actor Loss: -3.3256
# Episode: 740 Timestep: 93894 Total reward: -159.5 Episode length: 62.5 Loss: 4498.5684 Actor Loss: -0.3617
# Episode: 750 Timestep: 94568 Total reward: -188.6 Episode length: 67.4 Loss: 4932.4233 Actor Loss: -1.1509
# Episode: 760 Timestep: 95291 Total reward: -180.3 Episode length: 72.3 Loss: 5793.4056 Actor Loss: -0.8334
# Episode: 770 Timestep: 96074 Total reward: -173.8 Episode length: 78.3 Loss: 5967.1783 Actor Loss: -1.0972
# Episode: 780 Timestep: 96733 Total reward: -197.0 Episode length: 65.9 Loss: 5127.3932 Actor Loss: -1.2117
# Episode: 790 Timestep: 97390 Total reward: -190.8 Episode length: 65.7 Loss: 5523.8230 Actor Loss: 0.0691
# Episode: 800 Timestep: 98119 Total reward: -170.7 Episode length: 72.9 Loss: 5931.4632 Actor Loss: -2.7950
# Episode: 810 Timestep: 98778 Total reward: -215.5 Episode length: 65.9 Loss: 5599.2917 Actor Loss: -2.5338
# Episode: 820 Timestep: 99480 Total reward: -200.8 Episode length: 70.2 Loss: 5437.2954 Actor Loss: -0.6206
# Episode: 830 Timestep: 100139 Total reward: -222.8 Episode length: 65.9 Loss: 5861.9656 Actor Loss: -0.1058
# Episode: 840 Timestep: 100795 Total reward: -218.1 Episode length: 65.6 Loss: 5557.4433 Actor Loss: -1.9605
# Episode: 850 Timestep: 101400 Total reward: -187.4 Episode length: 60.5 Loss: 4821.9071 Actor Loss: 0.1348
# Episode: 860 Timestep: 102062 Total reward: -132.5 Episode length: 66.2 Loss: 5943.1756 Actor Loss: -2.7926
# Episode: 870 Timestep: 102661 Total reward: -244.7 Episode length: 59.9 Loss: 5068.6899 Actor Loss: -0.2614
# Episode: 880 Timestep: 103285 Total reward: -207.4 Episode length: 62.4 Loss: 5164.3262 Actor Loss: -3.9466
# Episode: 890 Timestep: 104073 Total reward: -183.1 Episode length: 78.8 Loss: 6727.4403 Actor Loss: -8.4919
# Episode: 900 Timestep: 104734 Total reward: -218.4 Episode length: 66.1 Loss: 5512.7045 Actor Loss: -0.1271
# Episode: 910 Timestep: 105301 Total reward: -217.5 Episode length: 56.7 Loss: 4795.5894 Actor Loss: 0.1778
# Episode: 920 Timestep: 105997 Total reward: -153.6 Episode length: 69.6 Loss: 6054.4360 Actor Loss: -0.2994
# Episode: 930 Timestep: 106598 Total reward: -174.7 Episode length: 60.1 Loss: 5130.4567 Actor Loss: -0.1052
# Episode: 940 Timestep: 107258 Total reward: -175.5 Episode length: 66.0 Loss: 5737.2909 Actor Loss: -0.1826
# Episode: 950 Timestep: 107919 Total reward: -176.0 Episode length: 66.1 Loss: 5999.4751 Actor Loss: -0.6116
# Episode: 960 Timestep: 108552 Total reward: -170.7 Episode length: 63.3 Loss: 5313.8554 Actor Loss: -0.6581
# Episode: 970 Timestep: 109192 Total reward: -196.0 Episode length: 64.0 Loss: 5575.6254 Actor Loss: -0.3630
# Episode: 980 Timestep: 109847 Total reward: -189.9 Episode length: 65.5 Loss: 5453.8836 Actor Loss: -0.5500
# Episode: 990 Timestep: 110484 Total reward: -193.0 Episode length: 63.7 Loss: 5127.5077 Actor Loss: -0.1917
# Episode: 1000 Timestep: 111091 Total reward: -182.4 Episode length: 60.7 Loss: 5121.1766 Actor Loss: 0.0774
# Episode: 1010 Timestep: 111705 Total reward: -164.9 Episode length: 61.4 Loss: 4742.4709 Actor Loss: -0.3562
# Episode: 1020 Timestep: 112344 Total reward: -196.5 Episode length: 63.9 Loss: 5249.4079 Actor Loss: -1.4000
# Episode: 1030 Timestep: 112917 Total reward: -228.5 Episode length: 57.3 Loss: 4472.2227 Actor Loss: -0.0778
# Episode: 1040 Timestep: 113497 Total reward: -210.4 Episode length: 58.0 Loss: 4623.6036 Actor Loss: -1.3003
# Episode: 1050 Timestep: 114093 Total reward: -216.9 Episode length: 59.6 Loss: 4282.5970 Actor Loss: -0.4057
# Episode: 1060 Timestep: 114653 Total reward: -231.9 Episode length: 56.0 Loss: 4198.6756 Actor Loss: 0.1021
# Episode: 1070 Timestep: 115237 Total reward: -217.6 Episode length: 58.4 Loss: 4335.8630 Actor Loss: -2.3657
# Episode: 1080 Timestep: 115745 Total reward: -243.2 Episode length: 50.8 Loss: 3679.0696 Actor Loss: -0.0162
# Episode: 1090 Timestep: 116237 Total reward: -264.1 Episode length: 49.2 Loss: 3663.7278 Actor Loss: 0.1756
# Episode: 1100 Timestep: 116762 Total reward: -249.3 Episode length: 52.5 Loss: 4043.8307 Actor Loss: 0.0027
# Episode: 1110 Timestep: 117232 Total reward: -257.7 Episode length: 47.0 Loss: 3559.2784 Actor Loss: 0.0002
# Episode: 1120 Timestep: 117730 Total reward: -243.1 Episode length: 49.8 Loss: 3439.3496 Actor Loss: -0.2362
# Episode: 1130 Timestep: 118193 Total reward: -265.4 Episode length: 46.3 Loss: 3214.8562 Actor Loss: -1.2622
# Episode: 1140 Timestep: 118722 Total reward: -246.6 Episode length: 52.9 Loss: 3374.6778 Actor Loss: -1.6107
# Episode: 1150 Timestep: 119182 Total reward: -257.5 Episode length: 46.0 Loss: 3165.2453 Actor Loss: 0.0000
# Episode: 1160 Timestep: 119634 Total reward: -254.2 Episode length: 45.2 Loss: 3053.1834 Actor Loss: 0.0000
# Episode: 1170 Timestep: 120075 Total reward: -255.0 Episode length: 44.1 Loss: 2921.8244 Actor Loss: -0.0000
# Episode: 1180 Timestep: 120529 Total reward: -255.5 Episode length: 45.4 Loss: 2903.6269 Actor Loss: -0.0000
# Episode: 1190 Timestep: 120975 Total reward: -256.2 Episode length: 44.6 Loss: 3041.5550 Actor Loss: 0.0000
# Episode: 1200 Timestep: 121437 Total reward: -255.9 Episode length: 46.2 Loss: 3171.4685 Actor Loss: -0.0000
# Episode: 1210 Timestep: 121895 Total reward: -255.0 Episode length: 45.8 Loss: 2894.9190 Actor Loss: 0.0000
# Episode: 1220 Timestep: 122354 Total reward: -255.6 Episode length: 45.9 Loss: 3158.8239 Actor Loss: 0.0000
# Episode: 1230 Timestep: 122806 Total reward: -255.0 Episode length: 45.2 Loss: 2700.0277 Actor Loss: 0.0000
# Episode: 1240 Timestep: 123253 Total reward: -254.8 Episode length: 44.7 Loss: 2673.4824 Actor Loss: -0.0008
# Episode: 1250 Timestep: 123712 Total reward: -256.6 Episode length: 45.9 Loss: 2905.9039 Actor Loss: 0.0000
# Episode: 1260 Timestep: 124157 Total reward: -252.2 Episode length: 44.5 Loss: 2740.4842 Actor Loss: -0.0074
# Episode: 1270 Timestep: 124618 Total reward: -255.3 Episode length: 46.1 Loss: 3033.5940 Actor Loss: 0.0000
# Episode: 1280 Timestep: 125079 Total reward: -254.7 Episode length: 46.1 Loss: 2951.0442 Actor Loss: -0.1632
# Episode: 1290 Timestep: 125558 Total reward: -254.4 Episode length: 47.9 Loss: 3245.0330 Actor Loss: -1.3589
# Episode: 1300 Timestep: 126006 Total reward: -263.8 Episode length: 44.8 Loss: 2754.4424 Actor Loss: 0.0000
# Episode: 1310 Timestep: 126447 Total reward: -255.4 Episode length: 44.1 Loss: 2737.1752 Actor Loss: 0.0000
# Episode: 1320 Timestep: 126912 Total reward: -263.6 Episode length: 46.5 Loss: 2702.7341 Actor Loss: 0.0000
# Episode: 1330 Timestep: 127374 Total reward: -270.0 Episode length: 46.2 Loss: 2845.8711 Actor Loss: -0.0741
# Episode: 1340 Timestep: 127880 Total reward: -279.2 Episode length: 50.6 Loss: 3343.1704 Actor Loss: -6.8403
# Episode: 1350 Timestep: 128364 Total reward: -280.9 Episode length: 48.4 Loss: 2790.2916 Actor Loss: -3.2410
# Episode: 1360 Timestep: 128840 Total reward: -254.4 Episode length: 47.6 Loss: 3096.4241 Actor Loss: 0.0000
# Episode: 1370 Timestep: 129284 Total reward: -261.6 Episode length: 44.4 Loss: 3114.5403 Actor Loss: -0.0000
# Episode: 1380 Timestep: 129755 Total reward: -254.3 Episode length: 47.1 Loss: 3072.4926 Actor Loss: 0.0000
# Episode: 1390 Timestep: 130229 Total reward: -254.5 Episode length: 47.4 Loss: 2912.1852 Actor Loss: -0.0018
# Episode: 1400 Timestep: 130667 Total reward: -253.4 Episode length: 43.8 Loss: 2605.8193 Actor Loss: -0.0001
# Episode: 1410 Timestep: 131135 Total reward: -264.0 Episode length: 46.8 Loss: 3146.0778 Actor Loss: 0.0000
# Episode: 1420 Timestep: 131613 Total reward: -261.8 Episode length: 47.8 Loss: 3217.5591 Actor Loss: 0.0000
# Episode: 1430 Timestep: 132095 Total reward: -255.3 Episode length: 48.2 Loss: 2882.6773 Actor Loss: 0.0000
# Episode: 1440 Timestep: 132552 Total reward: -256.2 Episode length: 45.7 Loss: 2976.3173 Actor Loss: 0.0000
# Episode: 1450 Timestep: 133031 Total reward: -262.4 Episode length: 47.9 Loss: 2872.0130 Actor Loss: -0.0000
# Episode: 1460 Timestep: 133498 Total reward: -265.0 Episode length: 46.7 Loss: 2989.4559 Actor Loss: -0.0000
# Episode: 1470 Timestep: 133957 Total reward: -254.1 Episode length: 45.9 Loss: 2748.3638 Actor Loss: 0.0000
# Episode: 1480 Timestep: 134407 Total reward: -254.1 Episode length: 45.0 Loss: 3000.1756 Actor Loss: 0.0000
# Episode: 1490 Timestep: 134881 Total reward: -261.2 Episode length: 47.4 Loss: 2895.6552 Actor Loss: 0.0000
# Episode: 1500 Timestep: 135363 Total reward: -240.6 Episode length: 48.2 Loss: 3078.2739 Actor Loss: -2.5482
# Episode: 1510 Timestep: 135883 Total reward: -251.2 Episode length: 52.0 Loss: 3619.6128 Actor Loss: -3.9821
# Episode: 1520 Timestep: 136327 Total reward: -253.0 Episode length: 44.4 Loss: 2776.9004 Actor Loss: 0.0000
# Episode: 1530 Timestep: 136780 Total reward: -273.4 Episode length: 45.3 Loss: 2861.0169 Actor Loss: -0.0653
# Episode: 1540 Timestep: 137231 Total reward: -255.5 Episode length: 45.1 Loss: 2923.1967 Actor Loss: -0.0084
# Episode: 1550 Timestep: 137725 Total reward: -262.9 Episode length: 49.4 Loss: 3105.0652 Actor Loss: -2.2272
# Episode: 1560 Timestep: 138191 Total reward: -254.7 Episode length: 46.6 Loss: 3174.9103 Actor Loss: 0.0000
# Episode: 1570 Timestep: 138651 Total reward: -254.3 Episode length: 46.0 Loss: 2800.9504 Actor Loss: 0.0000
# Episode: 1580 Timestep: 139093 Total reward: -253.6 Episode length: 44.2 Loss: 2976.4308 Actor Loss: 0.0000
# Episode: 1590 Timestep: 139536 Total reward: -254.5 Episode length: 44.3 Loss: 2894.4705 Actor Loss: 0.0000
# Episode: 1600 Timestep: 139976 Total reward: -253.5 Episode length: 44.0 Loss: 2912.8818 Actor Loss: 0.0000
# Episode: 1610 Timestep: 140435 Total reward: -255.2 Episode length: 45.9 Loss: 3062.5473 Actor Loss: 0.0000
# Episode: 1620 Timestep: 140902 Total reward: -255.8 Episode length: 46.7 Loss: 3322.1137 Actor Loss: 0.0000
# Episode: 1630 Timestep: 141372 Total reward: -260.8 Episode length: 47.0 Loss: 3138.4145 Actor Loss: 0.0000
# Episode: 1640 Timestep: 141833 Total reward: -256.8 Episode length: 46.1 Loss: 3193.0998 Actor Loss: 0.0000
# Episode: 1650 Timestep: 142296 Total reward: -257.1 Episode length: 46.3 Loss: 3111.6883 Actor Loss: 0.0000
# Episode: 1660 Timestep: 142751 Total reward: -265.5 Episode length: 45.5 Loss: 3439.7042 Actor Loss: 0.0000
# Episode: 1670 Timestep: 143232 Total reward: -261.8 Episode length: 48.1 Loss: 3697.6322 Actor Loss: 0.0000
# Episode: 1680 Timestep: 143679 Total reward: -254.0 Episode length: 44.7 Loss: 3378.4774 Actor Loss: 0.0000
# Episode: 1690 Timestep: 144142 Total reward: -255.1 Episode length: 46.3 Loss: 3402.3364 Actor Loss: 0.0000
# Episode: 1700 Timestep: 144595 Total reward: -262.2 Episode length: 45.3 Loss: 3153.9416 Actor Loss: 0.0000
# Episode: 1710 Timestep: 145028 Total reward: -254.7 Episode length: 43.3 Loss: 3179.4305 Actor Loss: 0.0000
# Episode: 1720 Timestep: 145498 Total reward: -256.2 Episode length: 47.0 Loss: 3430.0201 Actor Loss: 0.0000
# Episode: 1730 Timestep: 145967 Total reward: -255.1 Episode length: 46.9 Loss: 3137.6607 Actor Loss: 0.0000
# Episode: 1740 Timestep: 146427 Total reward: -266.5 Episode length: 46.0 Loss: 3169.3417 Actor Loss: 0.0000
# Episode: 1750 Timestep: 146866 Total reward: -254.9 Episode length: 43.9 Loss: 3048.2268 Actor Loss: 0.0000
# Episode: 1760 Timestep: 147319 Total reward: -256.1 Episode length: 45.3 Loss: 3290.2287 Actor Loss: 0.0000
# Episode: 1770 Timestep: 147763 Total reward: -254.2 Episode length: 44.4 Loss: 3138.7368 Actor Loss: 0.0000
# Episode: 1780 Timestep: 148200 Total reward: -255.2 Episode length: 43.7 Loss: 3255.7177 Actor Loss: 0.0000
# Episode: 1790 Timestep: 148653 Total reward: -262.3 Episode length: 45.3 Loss: 3310.4625 Actor Loss: 0.0000
# Episode: 1800 Timestep: 149083 Total reward: -255.7 Episode length: 43.0 Loss: 2675.8641 Actor Loss: 0.0000
# Episode: 1810 Timestep: 149519 Total reward: -256.3 Episode length: 43.6 Loss: 3165.4133 Actor Loss: 0.0000
# Episode: 1820 Timestep: 149966 Total reward: -254.9 Episode length: 44.7 Loss: 3368.6670 Actor Loss: 0.0000
# Episode: 1830 Timestep: 150426 Total reward: -253.8 Episode length: 46.0 Loss: 4002.7766 Actor Loss: 0.0000
# Episode: 1840 Timestep: 150874 Total reward: -256.6 Episode length: 44.8 Loss: 3653.8924 Actor Loss: 0.0000
# Episode: 1850 Timestep: 151320 Total reward: -256.9 Episode length: 44.6 Loss: 3475.8284 Actor Loss: 0.0000
# Episode: 1860 Timestep: 151766 Total reward: -256.4 Episode length: 44.6 Loss: 3823.3726 Actor Loss: 0.0000
# Episode: 1870 Timestep: 152216 Total reward: -254.6 Episode length: 45.0 Loss: 4160.7596 Actor Loss: 0.0000
# Episode: 1880 Timestep: 152691 Total reward: -254.9 Episode length: 47.5 Loss: 3852.5762 Actor Loss: 0.0000
# Episode: 1890 Timestep: 153159 Total reward: -256.8 Episode length: 46.8 Loss: 3694.3318 Actor Loss: 0.0000
# Episode: 1900 Timestep: 153617 Total reward: -254.9 Episode length: 45.8 Loss: 3539.2552 Actor Loss: 0.0000
# Episode: 1910 Timestep: 154081 Total reward: -254.4 Episode length: 46.4 Loss: 4027.3877 Actor Loss: 0.0000
# Episode: 1920 Timestep: 154538 Total reward: -255.7 Episode length: 45.7 Loss: 3959.8033 Actor Loss: 0.0000
# Episode: 1930 Timestep: 155014 Total reward: -255.8 Episode length: 47.6 Loss: 4607.8662 Actor Loss: 0.0000
# Episode: 1940 Timestep: 155463 Total reward: -256.0 Episode length: 44.9 Loss: 4145.5645 Actor Loss: 0.0000
# Episode: 1950 Timestep: 155912 Total reward: -256.0 Episode length: 44.9 Loss: 3834.0773 Actor Loss: 0.0000
# Episode: 1960 Timestep: 156381 Total reward: -256.3 Episode length: 46.9 Loss: 3595.1895 Actor Loss: 0.0000
# Episode: 1970 Timestep: 156830 Total reward: -256.4 Episode length: 44.9 Loss: 3796.5786 Actor Loss: 0.0000
# Episode: 1980 Timestep: 157290 Total reward: -256.3 Episode length: 46.0 Loss: 5170.2713 Actor Loss: 0.0000
# Episode: 1990 Timestep: 157741 Total reward: -255.3 Episode length: 45.1 Loss: 5615.3037 Actor Loss: 0.0000
# Episode: 2000 Timestep: 158195 Total reward: -256.1 Episode length: 45.4 Loss: 4665.4191 Actor Loss: 0.0000
# Episode: 2010 Timestep: 158649 Total reward: -254.4 Episode length: 45.4 Loss: 4810.1195 Actor Loss: 0.0000
# Episode: 2020 Timestep: 159107 Total reward: -255.6 Episode length: 45.8 Loss: 4313.3134 Actor Loss: 0.0000
# Episode: 2030 Timestep: 159536 Total reward: -256.0 Episode length: 42.9 Loss: 4628.1376 Actor Loss: 0.0000
# Episode: 2040 Timestep: 160018 Total reward: -261.8 Episode length: 48.2 Loss: 5564.6142 Actor Loss: 0.0000
# Episode: 2050 Timestep: 160466 Total reward: -255.4 Episode length: 44.8 Loss: 6052.2609 Actor Loss: 0.0000
# Episode: 2060 Timestep: 160937 Total reward: -261.7 Episode length: 47.1 Loss: 5818.4619 Actor Loss: 0.0000
# Episode: 2070 Timestep: 161382 Total reward: -254.5 Episode length: 44.5 Loss: 5274.4499 Actor Loss: 0.0000
# Episode: 2080 Timestep: 161832 Total reward: -256.0 Episode length: 45.0 Loss: 5477.4434 Actor Loss: 0.0000
# Episode: 2090 Timestep: 162283 Total reward: -256.4 Episode length: 45.1 Loss: 5697.3746 Actor Loss: 0.0000
# Episode: 2100 Timestep: 162730 Total reward: -255.6 Episode length: 44.7 Loss: 7189.9586 Actor Loss: 0.0000
# Episode: 2110 Timestep: 163200 Total reward: -263.4 Episode length: 47.0 Loss: 5627.5984 Actor Loss: 0.0000
# Episode: 2120 Timestep: 163656 Total reward: -255.5 Episode length: 45.6 Loss: 4852.7278 Actor Loss: 0.0000
# Episode: 2130 Timestep: 164128 Total reward: -255.8 Episode length: 47.2 Loss: 5082.2987 Actor Loss: 0.0000
# Episode: 2140 Timestep: 164596 Total reward: -254.5 Episode length: 46.8 Loss: 4924.3932 Actor Loss: 0.0000
# Episode: 2150 Timestep: 165040 Total reward: -256.6 Episode length: 44.4 Loss: 5667.4210 Actor Loss: 0.0000
# Episode: 2160 Timestep: 165517 Total reward: -270.4 Episode length: 47.7 Loss: 5348.9445 Actor Loss: 0.0000
# Episode: 2170 Timestep: 165978 Total reward: -256.3 Episode length: 46.1 Loss: 5534.4321 Actor Loss: 0.0000
# Episode: 2180 Timestep: 166432 Total reward: -255.7 Episode length: 45.4 Loss: 5697.0579 Actor Loss: 0.0000
# Episode: 2190 Timestep: 166895 Total reward: -256.5 Episode length: 46.3 Loss: 5558.0113 Actor Loss: 0.0000
# Episode: 2200 Timestep: 167338 Total reward: -254.9 Episode length: 44.3 Loss: 5685.0984 Actor Loss: 0.0000
# Episode: 2210 Timestep: 167828 Total reward: -255.2 Episode length: 49.0 Loss: 6117.1817 Actor Loss: 0.0000
# Episode: 2220 Timestep: 168286 Total reward: -269.0 Episode length: 45.8 Loss: 6204.5298 Actor Loss: 0.0000
# Episode: 2230 Timestep: 168748 Total reward: -253.1 Episode length: 46.2 Loss: 5342.7774 Actor Loss: 0.0000
# Episode: 2240 Timestep: 169212 Total reward: -263.7 Episode length: 46.4 Loss: 6294.0202 Actor Loss: 0.0000
# Episode: 2250 Timestep: 169675 Total reward: -257.2 Episode length: 46.3 Loss: 6435.6862 Actor Loss: 0.0000
# Episode: 2260 Timestep: 170107 Total reward: -255.9 Episode length: 43.2 Loss: 6315.7501 Actor Loss: 0.0000
# Episode: 2270 Timestep: 170572 Total reward: -256.5 Episode length: 46.5 Loss: 6758.6954 Actor Loss: 0.0000
# Episode: 2280 Timestep: 171043 Total reward: -257.5 Episode length: 47.1 Loss: 6791.2081 Actor Loss: 0.0000
# Episode: 2290 Timestep: 171517 Total reward: -254.9 Episode length: 47.4 Loss: 7133.2977 Actor Loss: 0.0000
# Episode: 2300 Timestep: 171973 Total reward: -264.8 Episode length: 45.6 Loss: 7183.0814 Actor Loss: 0.0000
# Episode: 2310 Timestep: 172445 Total reward: -262.8 Episode length: 47.2 Loss: 7023.4734 Actor Loss: 0.0000
# Episode: 2320 Timestep: 172921 Total reward: -255.0 Episode length: 47.6 Loss: 6828.1521 Actor Loss: 0.0000
# Episode: 2330 Timestep: 173369 Total reward: -252.9 Episode length: 44.8 Loss: 6487.7250 Actor Loss: 0.0000
# Episode: 2340 Timestep: 173816 Total reward: -256.6 Episode length: 44.7 Loss: 6660.9112 Actor Loss: 0.0000
# Episode: 2350 Timestep: 174267 Total reward: -256.4 Episode length: 45.1 Loss: 6508.0846 Actor Loss: 0.0000
# Episode: 2360 Timestep: 174734 Total reward: -257.1 Episode length: 46.7 Loss: 7318.7138 Actor Loss: 0.0000
# Episode: 2370 Timestep: 175204 Total reward: -262.7 Episode length: 47.0 Loss: 7231.5651 Actor Loss: 0.0000
# Episode: 2380 Timestep: 175654 Total reward: -256.1 Episode length: 45.0 Loss: 6464.8194 Actor Loss: 0.0000
# Episode: 2390 Timestep: 176107 Total reward: -255.8 Episode length: 45.3 Loss: 7763.9621 Actor Loss: 0.0000
# Episode: 2400 Timestep: 176557 Total reward: -254.5 Episode length: 45.0 Loss: 6894.6670 Actor Loss: 0.0000
# Episode: 2410 Timestep: 177014 Total reward: -262.9 Episode length: 45.7 Loss: 6994.0194 Actor Loss: 0.0000
# Episode: 2420 Timestep: 177461 Total reward: -253.4 Episode length: 44.7 Loss: 7140.3299 Actor Loss: 0.0000
# Episode: 2430 Timestep: 177918 Total reward: -255.3 Episode length: 45.7 Loss: 7755.3685 Actor Loss: 0.0000
# Episode: 2440 Timestep: 178363 Total reward: -254.3 Episode length: 44.5 Loss: 6208.1382 Actor Loss: 0.0000
# Episode: 2450 Timestep: 178813 Total reward: -255.6 Episode length: 45.0 Loss: 6892.2998 Actor Loss: 0.0000
# Episode: 2460 Timestep: 179266 Total reward: -255.2 Episode length: 45.3 Loss: 6166.9604 Actor Loss: 0.0000
# Episode: 2470 Timestep: 179748 Total reward: -263.6 Episode length: 48.2 Loss: 7058.3098 Actor Loss: 0.0000
# Episode: 2480 Timestep: 180208 Total reward: -254.6 Episode length: 46.0 Loss: 7734.3293 Actor Loss: 0.0000
# Episode: 2490 Timestep: 180686 Total reward: -255.2 Episode length: 47.8 Loss: 6832.0076 Actor Loss: 0.0000
# Episode: 2500 Timestep: 181138 Total reward: -254.5 Episode length: 45.2 Loss: 6750.1093 Actor Loss: 0.0000
# Episode: 2510 Timestep: 181613 Total reward: -255.5 Episode length: 47.5 Loss: 7968.0595 Actor Loss: 0.0000
# Episode: 2520 Timestep: 182087 Total reward: -264.4 Episode length: 47.4 Loss: 7519.7105 Actor Loss: 0.0000
# Episode: 2530 Timestep: 182556 Total reward: -254.1 Episode length: 46.9 Loss: 6776.1541 Actor Loss: 0.0000
# Episode: 2540 Timestep: 183000 Total reward: -253.4 Episode length: 44.4 Loss: 6595.3362 Actor Loss: 0.0000
# Episode: 2550 Timestep: 183447 Total reward: -261.5 Episode length: 44.7 Loss: 6097.5530 Actor Loss: 0.0000
# Episode: 2560 Timestep: 183905 Total reward: -253.6 Episode length: 45.8 Loss: 6603.0418 Actor Loss: 0.0000
# Episode: 2570 Timestep: 184364 Total reward: -255.6 Episode length: 45.9 Loss: 6482.3393 Actor Loss: 0.0000
# Episode: 2580 Timestep: 184839 Total reward: -254.8 Episode length: 47.5 Loss: 6829.3929 Actor Loss: 0.0000
# Episode: 2590 Timestep: 185296 Total reward: -257.1 Episode length: 45.7 Loss: 6017.8333 Actor Loss: 0.0000
# Episode: 2600 Timestep: 185753 Total reward: -254.4 Episode length: 45.7 Loss: 6486.3194 Actor Loss: 0.0000
# Episode: 2610 Timestep: 186197 Total reward: -253.4 Episode length: 44.4 Loss: 6150.3559 Actor Loss: 0.0000
# Episode: 2620 Timestep: 186651 Total reward: -265.8 Episode length: 45.4 Loss: 7386.1467 Actor Loss: 0.0000
# Episode: 2630 Timestep: 187113 Total reward: -254.9 Episode length: 46.2 Loss: 7075.6315 Actor Loss: 0.0000
# Episode: 2640 Timestep: 187558 Total reward: -261.6 Episode length: 44.5 Loss: 5723.0942 Actor Loss: -0.0000
# Episode: 2650 Timestep: 187996 Total reward: -255.0 Episode length: 43.8 Loss: 6251.4903 Actor Loss: 0.0000
# Episode: 2660 Timestep: 188436 Total reward: -256.0 Episode length: 44.0 Loss: 6719.4559 Actor Loss: 0.0000
# Episode: 2670 Timestep: 188907 Total reward: -256.5 Episode length: 47.1 Loss: 6724.9707 Actor Loss: 0.0000
# Episode: 2680 Timestep: 189357 Total reward: -254.2 Episode length: 45.0 Loss: 6071.5542 Actor Loss: 0.0000
# Episode: 2690 Timestep: 189812 Total reward: -254.8 Episode length: 45.5 Loss: 6317.9515 Actor Loss: 0.0000
# Episode: 2700 Timestep: 190259 Total reward: -256.0 Episode length: 44.7 Loss: 6208.3104 Actor Loss: 0.0000
# Episode: 2710 Timestep: 190699 Total reward: -256.6 Episode length: 44.0 Loss: 6287.2539 Actor Loss: 0.0000
# Episode: 2720 Timestep: 191156 Total reward: -255.8 Episode length: 45.7 Loss: 6431.7970 Actor Loss: 0.0000
# Episode: 2730 Timestep: 191603 Total reward: -255.5 Episode length: 44.7 Loss: 5981.1391 Actor Loss: 0.0000
# Episode: 2740 Timestep: 192073 Total reward: -265.0 Episode length: 47.0 Loss: 6909.3991 Actor Loss: 0.0000
# Episode: 2750 Timestep: 192559 Total reward: -254.4 Episode length: 48.6 Loss: 6424.8529 Actor Loss: 0.0000
# Episode: 2760 Timestep: 193017 Total reward: -254.0 Episode length: 45.8 Loss: 5740.1785 Actor Loss: 0.0000
# Episode: 2770 Timestep: 193470 Total reward: -253.2 Episode length: 45.3 Loss: 6338.5712 Actor Loss: 0.0000
# Episode: 2780 Timestep: 193933 Total reward: -265.6 Episode length: 46.3 Loss: 6170.5037 Actor Loss: 0.0000
# Episode: 2790 Timestep: 194407 Total reward: -264.8 Episode length: 47.4 Loss: 6306.9071 Actor Loss: 0.0000
# Episode: 2800 Timestep: 194862 Total reward: -255.5 Episode length: 45.5 Loss: 6200.6122 Actor Loss: 0.0000
# Episode: 2810 Timestep: 195318 Total reward: -263.4 Episode length: 45.6 Loss: 5552.1591 Actor Loss: 0.0000
# Episode: 2820 Timestep: 195778 Total reward: -256.1 Episode length: 46.0 Loss: 5499.1548 Actor Loss: 0.0000
# Episode: 2830 Timestep: 196220 Total reward: -254.8 Episode length: 44.2 Loss: 6171.4364 Actor Loss: 0.0000
# Episode: 2840 Timestep: 196686 Total reward: -256.0 Episode length: 46.6 Loss: 5506.4552 Actor Loss: 0.0000
# Episode: 2850 Timestep: 197132 Total reward: -253.6 Episode length: 44.6 Loss: 5721.2613 Actor Loss: 0.0000
# Episode: 2860 Timestep: 197581 Total reward: -264.9 Episode length: 44.9 Loss: 5731.5238 Actor Loss: 0.0000
# Episode: 2870 Timestep: 198049 Total reward: -254.3 Episode length: 46.8 Loss: 5577.6732 Actor Loss: 0.0000
# Episode: 2880 Timestep: 198500 Total reward: -253.8 Episode length: 45.1 Loss: 5285.7629 Actor Loss: 0.0000
# Episode: 2890 Timestep: 198956 Total reward: -254.6 Episode length: 45.6 Loss: 5238.6198 Actor Loss: 0.0000
# Episode: 2900 Timestep: 199424 Total reward: -255.6 Episode length: 46.8 Loss: 5701.8027 Actor Loss: 0.0000
# Episode: 2910 Timestep: 199870 Total reward: -255.8 Episode length: 44.6 Loss: 5386.7010 Actor Loss: 0.0000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 34
#      31 done_list.append(1. - float(termination))
#      33 # train the actor
# ---> 34 actor_loss, critic_loss = agent.train_actor(state_list, action_list, reward_list, next_state_list, done_list)
#      35 stats_actor_loss.append(actor_loss)
#      36 stats_critic_loss.append(critic_loss)
#
# TypeError: iteration over a 0-d array

# %%
# plot stats
def get_running_stat(stat, stat_len):
    cum_sum = np.cumsum(np.insert(stat, 0, 0)) 
    return (cum_sum[stat_len:] - cum_sum[:-stat_len]) / stat_len

episode, r, l = np.array(stats_rewards_list).T
cum_r = get_running_stat(r, 10)
cum_l = get_running_stat(l, 10)

# plot rewards
plt.plot(episode[-len(cum_r):], cum_r)
plt.plot(episode, r, alpha=0.5)
plt.xlabel('Episode')
plt.ylabel('Episode Reward')
# Out:
# Text(0, 0.5, 'Episode Reward')

# %%
# plot episode lengths
plt.plot(episode[-len(cum_l):], cum_l)
plt.plot(episode, l, alpha=0.5)
plt.xlabel('Episode')
plt.ylabel('Episode Length')
# Out:
# Text(0, 0.5, 'Episode Length')
